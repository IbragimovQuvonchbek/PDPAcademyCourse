# %%
import matplotlib.pyplot as plt

# %%
x = list(range(-125, 126))

y = [i**2 for i in x]

# %%
plt.plot(x, y)
plt.title('y = x^2 Kvadrat Funktsiyasi')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()
